# %% [markdown]
# ## Explore Sample Sales Data

# %%
import pandas as pd
from pathlib import Path

# %%
input_file = Path.cwd() / 'data' / 'raw' / 'sample_sales.xlsx'
#print(input_file)
df = pd.read_excel(input_file)

# %%
df
# Out:
#        invoice    company purchase_date product  quantity  price  \
# 0    ZN-870-29   Realcube    2019-03-05   shirt        19     17
# 1    JQ-501-63      Zooxo    2019-07-09    book        30     14
# 2    FI-165-58    Dabtype    2019-08-12  poster         7     23
# 3    XP-005-55   Skipfire    2019-11-18     pen         7     29
# 4    NB-917-18   Bluezoom    2019-04-18  poster        36     19
# ..         ...        ...           ...     ...       ...    ...
# 995  ZM-628-88       Viva    2019-09-11     pen        -5     34
# 996  DQ-810-46       Viva    2019-09-05     pen        17     32
# 997  RA-147-40    Dabfeed    2019-03-24  poster        17     34
# 998  VT-754-54  Photobean    2019-12-30   shirt        15     18
# 999  LS-463-74     Mybuzz    2019-11-12   shirt        24     34
#
#      extended amount
# 0                323
# 1                420
# 2                161
# 3                203
# 4                684
# ..               ...
# 995             -170
# ...

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  extended amount
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17              323
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14              420
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23              161
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29              203
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19              684

# %%
df.tail()
# Out:
#        invoice    company purchase_date product  quantity  price  \
# 995  ZM-628-88       Viva    2019-09-11     pen        -5     34
# 996  DQ-810-46       Viva    2019-09-05     pen        17     32
# 997  RA-147-40    Dabfeed    2019-03-24  poster        17     34
# 998  VT-754-54  Photobean    2019-12-30   shirt        15     18
# 999  LS-463-74     Mybuzz    2019-11-12   shirt        24     34
#
#      extended amount
# 995             -170
# 996              544
# 997              578
# 998              270
# 999              816

# %%
df.columns
# Out:
# Index(['invoice', 'company', 'purchase_date', 'product', 'quantity', 'price',
#        'extended amount'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of        invoice    company purchase_date product  quantity  price  \
# 0    ZN-870-29   Realcube    2019-03-05   shirt        19     17
# 1    JQ-501-63      Zooxo    2019-07-09    book        30     14
# 2    FI-165-58    Dabtype    2019-08-12  poster         7     23
# 3    XP-005-55   Skipfire    2019-11-18     pen         7     29
# 4    NB-917-18   Bluezoom    2019-04-18  poster        36     19
# ..         ...        ...           ...     ...       ...    ...
# 995  ZM-628-88       Viva    2019-09-11     pen        -5     34
# 996  DQ-810-46       Viva    2019-09-05     pen        17     32
# 997  RA-147-40    Dabfeed    2019-03-24  poster        17     34
# 998  VT-754-54  Photobean    2019-12-30   shirt        15     18
# 999  LS-463-74     Mybuzz    2019-11-12   shirt        24     34
#
#      extended amount
# 0                323
# 1                420
# 2                161
# 3                203
# 4                684
# ...

# %%
df.describe()
# Out:
#                     purchase_date     quantity        price  extended amount
# count                        1000  1000.000000  1000.000000      1000.000000
# mean   2019-07-04 17:41:16.800000    22.421000    22.816000       510.270000
# min           2019-01-01 00:00:00    -5.000000    10.000000      -170.000000
# 25%           2019-04-06 00:00:00     9.000000    16.000000       168.750000
# 50%           2019-07-04 12:00:00    22.000000    23.000000       435.000000
# 75%           2019-10-04 06:00:00    36.000000    29.000000       798.500000
# max           2019-12-30 00:00:00    50.000000    35.000000      1715.000000
# std                           NaN    16.246714     7.537039       426.411667

# %%
df['extended amount'].sum()
# Out:
# np.int64(510270)

# %%
df['extended amount'].mean()
# Out:
# np.float64(510.27)

# %%
df['invoice'].nunique()
# Out:
# 1000

# %%
df['product'].head()
# Out:
# 0     shirt
# 1      book
# 2    poster
# 3       pen
# 4    poster
# Name: product, dtype: object

# %%
df['product'].nunique()
# Out:
# 4

# %%
df['price'].count()
# Out:
# np.int64(1000)

# %%
df['product'].value_counts()
# Out:
# product
# shirt     271
# poster    269
# book      234
# pen       226
# Name: count, dtype: int64

# %%
df['product'].value_counts()
# Out:
# product
# shirt     271
# poster    269
# book      234
# pen       226
# Name: count, dtype: int64

# %%
df['product'].value_counts().div(100)
# Out:
# product
# shirt     2.71
# poster    2.69
# book      2.34
# pen       2.26
# Name: count, dtype: float64

# %%
df['product'].value_counts(normalize=True)
# Out:
# product
# shirt     0.271
# poster    0.269
# book      0.234
# pen       0.226
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  extended amount
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17              323
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14              420
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23              161
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29              203
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19              684

# %%
summary_columns = ['price', 'quantity']
df[summary_columns].mean()
# Out:
# price       22.816
# quantity    22.421
# dtype: float64

# %%
df[['quantity', 'price']].mean()
# Out:
# quantity    22.421
# price       22.816
# dtype: float64

# %%
df['Country'] = 'USA'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice          1000 non-null   object
#  1   company          1000 non-null   object
#  2   purchase_date    1000 non-null   datetime64[ns]
#  3   product          1000 non-null   object
#  4   quantity         1000 non-null   int64
#  5   price            1000 non-null   int64
#  6   extended amount  1000 non-null   int64
#  7   Country          1000 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 62.6+ KB

# %%
df['Fee'] = df['extended amount'] * 0.015

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19
#
#    extended amount Country     Fee
# 0              323     USA   48.45
# 1              420     USA   63.00
# 2              161     USA   24.15
# 3              203     USA   30.45
# 4              684     USA  102.60

# %% [markdown]
# ## Columns manipulaion

# %%
df.columns
# Out:
# Index(['invoice', 'company', 'purchase_date', 'product', 'quantity', 'price',
#        'extended amount', 'Country', 'Fee'],
#       dtype='object')

# %%
    list(df.columns)
# Out:
# ['invoice',
#  'company',
#  'purchase_date',
#  'product',
#  'quantity',
#  'price',
#  'extended amount',
#  'Country',
#  'Fee']

# %%
[c.replace(' ', '_') for c in df.columns]
# Out:
# ['invoice',
#  'company',
#  'purchase_date',
#  'product',
#  'quantity',
#  'price',
#  'extended_amount',
#  'Country',
#  'Fee']

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19
#
#    extended amount Country     Fee
# 0              323     USA   4.845
# 1              420     USA   6.300
# 2              161     USA   2.415
# 3              203     USA   3.045
# 4              684     USA  10.260

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19
#
#    extended_amount Country     Fee
# 0              323     USA   4.845
# 1              420     USA   6.300
# 2              161     USA   2.415
# 3              203     USA   3.045
# 4              684     USA  10.260

# %%
df.columns = [c.lower() for c in df.columns]

# %% [raw]
# df.head()

# %%
df.loc[0, :]
# Out:
# invoice                      ZN-870-29
# company                       Realcube
# purchase_date      2019-03-05 00:00:00
# product                          shirt
# quantity                            19
# price                               17
# extended amount                    323
# Name: 0, dtype: object

# %%
df.loc[[0,1,2,3,4], :]
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19
#
#    extended_amount country     fee
# 0              323     USA   4.845
# 1              420     USA   6.300
# 2              161     USA   2.415
# 3              203     USA   3.045
# 4              684     USA  10.260

# %%
df.loc[: , ['company', 'purchase_date', 'extended_amount']]
# Out:
#        company purchase_date  extended_amount
# 0     Realcube    2019-03-05              323
# 1        Zooxo    2019-07-09              420
# 2      Dabtype    2019-08-12              161
# 3     Skipfire    2019-11-18              203
# 4     Bluezoom    2019-04-18              684
# ..         ...           ...              ...
# 995       Viva    2019-09-11             -170
# 996       Viva    2019-09-05              544
# 997    Dabfeed    2019-03-24              578
# 998  Photobean    2019-12-30              270
# 999     Mybuzz    2019-11-12              816
#
# [1000 rows x 3 columns]

# %%
df.loc[: , 'company':'extended_amount']
# Out:
#        company purchase_date product  quantity  price  extended_amount
# 0     Realcube    2019-03-05   shirt        19     17              323
# 1        Zooxo    2019-07-09    book        30     14              420
# 2      Dabtype    2019-08-12  poster         7     23              161
# 3     Skipfire    2019-11-18     pen         7     29              203
# 4     Bluezoom    2019-04-18  poster        36     19              684
# ..         ...           ...     ...       ...    ...              ...
# 995       Viva    2019-09-11     pen        -5     34             -170
# 996       Viva    2019-09-05     pen        17     32              544
# 997    Dabfeed    2019-03-24  poster        17     34              578
# 998  Photobean    2019-12-30   shirt        15     18              270
# 999     Mybuzz    2019-11-12   shirt        24     34              816
#
# [1000 rows x 6 columns]

# %%
company_only = df.loc[:, 'company':'price'].copy()

# %%
print(company_only)
# Out:
#        company purchase_date product  quantity  price
# 0     Realcube    2019-03-05   shirt        19     17
# 1        Zooxo    2019-07-09    book        30     14
# 2      Dabtype    2019-08-12  poster         7     23
# 3     Skipfire    2019-11-18     pen         7     29
# 4     Bluezoom    2019-04-18  poster        36     19
# ..         ...           ...     ...       ...    ...
# 995       Viva    2019-09-11     pen        -5     34
# 996       Viva    2019-09-05     pen        17     32
# 997    Dabfeed    2019-03-24  poster        17     34
# 998  Photobean    2019-12-30   shirt        15     18
# 999     Mybuzz    2019-11-12   shirt        24     34
#
# [1000 rows x 5 columns]

# %%
df.iloc[:, 1:5]
# Out:
#        company purchase_date product  quantity
# 0     Realcube    2019-03-05   shirt        19
# 1        Zooxo    2019-07-09    book        30
# 2      Dabtype    2019-08-12  poster         7
# 3     Skipfire    2019-11-18     pen         7
# 4     Bluezoom    2019-04-18  poster        36
# ..         ...           ...     ...       ...
# 995       Viva    2019-09-11     pen        -5
# 996       Viva    2019-09-05     pen        17
# 997    Dabfeed    2019-03-24  poster        17
# 998  Photobean    2019-12-30   shirt        15
# 999     Mybuzz    2019-11-12   shirt        24
#
# [1000 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['invoice', 'company', 'purchase_date', 'product', 'quantity', 'price',
#        'extended amount'],
#       dtype='object')

# %%
df.iloc[0:5, 1:3]
# Out:
#     company purchase_date
# 0  Realcube    2019-03-05
# 1     Zooxo    2019-07-09
# 2   Dabtype    2019-08-12
# 3  Skipfire    2019-11-18
# 4  Bluezoom    2019-04-18

# %%
df.iloc[999,3]
# Out:
# 'shirt'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice          1000 non-null   object
#  1   company          1000 non-null   object
#  2   purchase_date    1000 non-null   datetime64[ns]
#  3   product          1000 non-null   object
#  4   quantity         1000 non-null   int64
#  5   price            1000 non-null   int64
#  6   extended amount  1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df['purchase_date'].dt.month
# Out:
# 0       3
# 1       7
# 2       8
# 3      11
# 4       4
#        ..
# 995     9
# 996     9
# 997     3
# 998    12
# 999    11
# Name: purchase_date, Length: 1000, dtype: int32

# %%
df['purchase_date'].dt.year
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 995    2019
# 996    2019
# 997    2019
# 998    2019
# 999    2019
# Name: purchase_date, Length: 1000, dtype: int32

# %%
df['purchase_date'].dt.dayofweek
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      3
#       ..
# 995    2
# 996    3
# 997    6
# 998    0
# 999    1
# Name: purchase_date, Length: 1000, dtype: int32

# %%
df['purchase_date'].dt.day
# Out:
# 0       5
# 1       9
# 2      12
# 3      18
# 4      18
#        ..
# 995    11
# 996     5
# 997    24
# 998    30
# 999    12
# Name: purchase_date, Length: 1000, dtype: int32

# %%
df['purchase_date'].dt.quarter
# Out:
# 0      1
# 1      3
# 2      3
# 3      4
# 4      2
#       ..
# 995    3
# 996    3
# 997    1
# 998    4
# 999    4
# Name: purchase_date, Length: 1000, dtype: int32

# %%
df['purchase_month'] = df['purchase_date'].dt.month
df['purchase_year'] = df['purchase_date'].dt.year
df['purchase_quarter'] = df['purchase_date'].dt.quarter

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice          1000 non-null   object
#  1   company          1000 non-null   object
#  2   purchase_date    1000 non-null   datetime64[ns]
#  3   product          1000 non-null   object
#  4   quantity         1000 non-null   int64
#  5   price            1000 non-null   int64
#  6   extended amount  1000 non-null   int64
#  7   purchase_month   1000 non-null   int32
#  8   purchase_year    1000 non-null   int32
# dtypes: datetime64[ns](1), int32(2), int64(3), object(3)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19
#
#    extended amount  purchase_month  purchase_year  purchase_quarter
# 0              323               3           2019                 1
# 1              420               7           2019                 3
# 2              161               8           2019                 3
# 3              203              11           2019                 4
# 4              684               4           2019                 2

# %% [markdown]
# ## Working with strings

# %%
df['company'].str.upper()
# Out:
# 0       REALCUBE
# 1          ZOOXO
# 2        DABTYPE
# 3       SKIPFIRE
# 4       BLUEZOOM
#          ...
# 995         VIVA
# 996         VIVA
# 997      DABFEED
# 998    PHOTOBEAN
# 999       MYBUZZ
# Name: company, Length: 1000, dtype: object

# %%
df['company'].str.lower()
# Out:
# 0       realcube
# 1          zooxo
# 2        dabtype
# 3       skipfire
# 4       bluezoom
#          ...
# 995         viva
# 996         viva
# 997      dabfeed
# 998    photobean
# 999       mybuzz
# Name: company, Length: 1000, dtype: object

# %%
df['company'].str.title()
# Out:
# 0       Realcube
# 1          Zooxo
# 2        Dabtype
# 3       Skipfire
# 4       Bluezoom
#          ...
# 995         Viva
# 996         Viva
# 997      Dabfeed
# 998    Photobean
# 999       Mybuzz
# Name: company, Length: 1000, dtype: object

# %%
df['company'].str.len()
# Out:
# 0      8
# 1      5
# 2      7
# 3      8
# 4      8
#       ..
# 995    4
# 996    4
# 997    7
# 998    9
# 999    6
# Name: company, Length: 1000, dtype: int64

# %%
df['extended amount'] * 0.9
# Out:
# 0      290.7
# 1      378.0
# 2      144.9
# 3      182.7
# 4      615.6
#        ...
# 995   -153.0
# 996    489.6
# 997    520.2
# 998    243.0
# 999    734.4
# Name: extended amount, Length: 1000, dtype: float64

# %%
df['extended amount'] .mul(.9)
# Out:
# 0      290.7
# 1      378.0
# 2      144.9
# 3      182.7
# 4      615.6
#        ...
# 995   -153.0
# 996    489.6
# 997    520.2
# 998    243.0
# 999    734.4
# Name: extended amount, Length: 1000, dtype: float64

# %%
df['new_price'] = df['price'] * 1.05
df['new_extended_quantity'] = df['new_price'] * df['quantity']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   invoice                1000 non-null   object
#  1   company                1000 non-null   object
#  2   purchase_date          1000 non-null   datetime64[ns]
#  3   product                1000 non-null   object
#  4   quantity               1000 non-null   int64
#  5   price                  1000 non-null   int64
#  6   extended amount        1000 non-null   int64
#  7   purchase_month         1000 non-null   int32
#  8   purchase_year          1000 non-null   int32
#  9   purchase_quarter       1000 non-null   int32
#  10  new_price              1000 non-null   float64
#  11  new_extended_quantity  1000 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int32(3), int64(3), object(3)
# memory usage: 82.2+ KB

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19
#
#    extended amount  purchase_month  purchase_year  purchase_quarter  \
# 0              323               3           2019                 1
# 1              420               7           2019                 3
# 2              161               8           2019                 3
# 3              203              11           2019                 4
# 4              684               4           2019                 2
#
#    new_price  new_extended_quantity
# 0      17.85                 339.15
# 1      14.70                 441.00
# 2      24.15                 169.05
# ...

# %%
df[['extended amount', 'new_extended_quantity']].sum()
# Out:
# extended amount          510270.0
# new_extended_quantity    535783.5
# dtype: float64

# %% [markdown]
# ## Filtering data in Panda with Boolean indexing and loc commands

# %%
df['company'] == 'Viva'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997    False
# 998    False
# 999    False
# Name: company, Length: 1000, dtype: bool

# %%
viva = df['company'] == 'Viva'

# %%
viva
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997    False
# 998    False
# 999    False
# Name: company, Length: 1000, dtype: bool

# %%
df.loc[viva, :]
# Out:
#        invoice company purchase_date product  quantity  price  \
# 186  CM-205-86    Viva    2019-05-19    book         8     14
# 705  QU-986-45    Viva    2019-06-09    book         6     35
# 840  RF-796-61    Viva    2019-02-19  poster        46     16
# 995  ZM-628-88    Viva    2019-09-11     pen        -5     34
# 996  DQ-810-46    Viva    2019-09-05     pen        17     32
#
#      extended amount  purchase_month  purchase_year  purchase_quarter  \
# 186              112               5           2019                 2
# 705              210               6           2019                 2
# 840              736               2           2019                 1
# 995             -170               9           2019                 3
# 996              544               9           2019                 3
#
#      new_price  new_extended_quantity
# 186      14.70                  117.6
# 705      36.75                  220.5
# 840      16.80                  772.8
# ...

# %%
df[viva]
# Out:
#        invoice company purchase_date product  quantity  price  \
# 186  CM-205-86    Viva    2019-05-19    book         8     14
# 705  QU-986-45    Viva    2019-06-09    book         6     35
# 840  RF-796-61    Viva    2019-02-19  poster        46     16
# 995  ZM-628-88    Viva    2019-09-11     pen        -5     34
# 996  DQ-810-46    Viva    2019-09-05     pen        17     32
#
#      extended amount  purchase_month  purchase_year  purchase_quarter  \
# 186              112               5           2019                 2
# 705              210               6           2019                 2
# 840              736               2           2019                 1
# 995             -170               9           2019                 3
# 996              544               9           2019                 3
#
#      new_price  new_extended_quantity
# 186      14.70                  117.6
# 705      36.75                  220.5
# 840      16.80                  772.8
# ...

# %%
qty_10 = (df['quantity'] >= 10)

# %%
qty_10
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: quantity, Length: 1000, dtype: bool

# %%
df.loc[(qty_10 & viva) , : ]
# Out:
#        invoice company purchase_date product  quantity  price  \
# 840  RF-796-61    Viva    2019-02-19  poster        46     16
# 996  DQ-810-46    Viva    2019-09-05     pen        17     32
#
#      extended amount  purchase_month  purchase_year  purchase_quarter  \
# 840              736               2           2019                 1
# 996              544               9           2019                 3
#
#      new_price  new_extended_quantity
# 840       16.8                  772.8
# 996       33.6                  571.2

# %%
df.loc[(qty_10 & viva) , 'purchase_date':'price' ]
# Out:
#     purchase_date product  quantity  price
# 840    2019-02-19  poster        46     16
# 996    2019-09-05     pen        17     32

# %%
df.loc[df['company'].str.contains('buzz'), :]
# Out:
#        invoice   company purchase_date product  quantity  price  \
# 23   NE-854-88  Realbuzz    2019-05-08  poster        11     14
# 48   NM-907-40    Mybuzz    2019-11-29  poster        11     26
# 153  KW-456-55  Realbuzz    2019-05-21  poster        38     22
# 206  GV-236-09  Linkbuzz    2019-06-25  poster        49     18
# 326  EY-555-15  Realbuzz    2019-04-18   shirt         0     12
# 470  SW-903-99  Realbuzz    2019-07-30  poster         6     29
# 589  HS-879-34    Mybuzz    2019-02-15  poster        36     30
# 687  LU-384-08  Linkbuzz    2019-01-15   shirt        35     35
# 947  YW-362-87  Linkbuzz    2019-12-11    book        45     17
# 999  LS-463-74    Mybuzz    2019-11-12   shirt        24     34
#
#      extended amount  purchase_month  purchase_year  purchase_quarter  \
# 23               154               5           2019                 2
# 48               286              11           2019                 4
# ...

# %% [markdown]
# ## Filtering with dates

# %%
df[df['purchase_date'] > '12-1-2019']
# Out:
#        invoice     company purchase_date product  quantity  price  \
# 32   MX-599-18       Vimbo    2019-12-12    book        36     33
# 33   NN-163-23      Skyble    2019-12-27     pen        45     12
# 34   FP-453-25        Zava    2019-12-05  poster         0     13
# 54   SI-328-34  Babbleblab    2019-12-13   shirt         3     34
# 57   JF-213-00    Centimia    2019-12-22     pen         6     17
# ..         ...         ...           ...     ...       ...    ...
# 951  HY-069-99         Oba    2019-12-12  poster        18     25
# 956  WO-091-32        Eire    2019-12-05   shirt        15     20
# 966  FO-483-27     Cogibox    2019-12-10  poster        25     15
# 985  DX-716-83       Aimbo    2019-12-17     pen        38     15
# 998  VT-754-54   Photobean    2019-12-30   shirt        15     18
#
#      extended amount  purchase_month  purchase_year  purchase_quarter  \
# 32              1188              12           2019                 4
# ...

# %%
purchase_date = df['purchase_date'].dt.month == 11
product_type = df['product'] == 'book'
df[purchase_date & product_type]
# Out:
#        invoice   company purchase_date product  quantity  price  \
# 16   IG-811-84     Yadel    2019-11-15    book        46     28
# 51   MM-603-72  Snaptags    2019-11-14    book        13     25
# 67   DB-217-08   Dynabox    2019-11-17    book        17     26
# 77   TL-625-84  Snaptags    2019-11-02    book        28     33
# 148  UE-108-04      Yodo    2019-11-24    book        29     27
# 194  CP-917-92     Kamba    2019-11-13    book        41     16
# 248  LZ-428-00  Photojam    2019-11-22    book         0     25
# 303  PE-226-53   Gabvine    2019-11-22    book        19     18
# 338  EP-683-72     Npath    2019-11-22    book         1     15
# 528  QP-747-38     Ainyx    2019-11-19    book         9     31
# 554  IK-877-78      Eayo    2019-11-04    book        19     28
# 555  OJ-368-07   Devcast    2019-11-11    book        36     11
# 576  RS-914-89    Skyndu    2019-11-13    book        -1     17
# 590  OQ-663-81      Muxo    2019-11-10    book         1     11
# ...

# %% [markdown]
# ## Create a variable like min_order_size =5, and a new column small orders where this number is less than min_order_size  and then return a table containing small orders  and all columns from company to product

# %%
min_order_size = 5
small_orders = df['quantity'] < min_order_size
df.loc[small_orders, 'company':'product']
# Out:
#         company purchase_date product
# 5        Zooveo    2019-10-17     pen
# 8      Buzzbean    2019-06-17  poster
# 19   Babbleblab    2019-10-23   shirt
# 24        Mynte    2019-11-25     pen
# 27         DabZ    2019-01-23     pen
# ..          ...           ...     ...
# 980       Roomm    2019-09-23     pen
# 981     Dabfeed    2019-03-25  poster
# 984   Reallinks    2019-06-24     pen
# 986       Jamia    2019-11-06   shirt
# 995        Viva    2019-09-11     pen
#
# [176 rows x 3 columns]

# %% [markdown]
# ## Querying the Panda dataframes

# %%
df.query('quantity > 10')
# Out:
#        invoice    company purchase_date product  quantity  price  \
# 0    ZN-870-29   Realcube    2019-03-05   shirt        19     17
# 1    JQ-501-63      Zooxo    2019-07-09    book        30     14
# 4    NB-917-18   Bluezoom    2019-04-18  poster        36     19
# 6    MQ-907-02  Babbleset    2019-10-27  poster        30     21
# 7    NX-102-26   Fliptune    2019-10-16    book        40     28
# ..         ...        ...           ...     ...       ...    ...
# 994  ON-247-90   Photobug    2019-09-29   shirt        40     31
# 996  DQ-810-46       Viva    2019-09-05     pen        17     32
# 997  RA-147-40    Dabfeed    2019-03-24  poster        17     34
# 998  VT-754-54  Photobean    2019-12-30   shirt        15     18
# 999  LS-463-74     Mybuzz    2019-11-12   shirt        24     34
#
#      extended amount  purchase_month  purchase_year  purchase_quarter  \
# 0                323               3           2019                 1
# ...

# %% [markdown]
# ## Aggregation in Panda - agg - aggregating

# %%
df['price'].agg(['mean', 'std', 'min', 'max'])
# Out:
# mean    22.816000
# std      7.537039
# min     10.000000
# max     35.000000
# Name: price, dtype: float64

# %%
df.agg(['min', 'max'])
# Out:
#        invoice company purchase_date product  quantity  price  \
# min  AC-761-69   Abatz    2019-01-01    book        -5     10
# max  ZY-479-41  Zoozzy    2019-12-30   shirt        50     35
#
#      extended amount  purchase_month  purchase_year  purchase_quarter  \
# min             -170               1           2019                 1
# max             1715              12           2019                 4
#
#      new_price  new_extended_quantity
# min      10.50                -178.50
# max      36.75                1800.75

# %%
columns_dictionary = {'quantity': 'sum',
                      'price': ['mean', 'std'],
                      'invoice': 'count',
                      'extended amount': 'sum'}

# %%
df.agg(columns_dictionary)
# Out:
#        quantity      price  invoice  extended amount
# sum     22421.0        NaN      NaN         510270.0
# mean        NaN  22.816000      NaN              NaN
# std         NaN   7.537039      NaN              NaN
# count       NaN        NaN   1000.0              NaN

# %%
df.agg(columns_dictionary).fillna(0)
# Out:
#        quantity      price  invoice  extended amount
# sum     22421.0   0.000000      0.0         510270.0
# mean        0.0  22.816000      0.0              0.0
# std         0.0   7.537039      0.0              0.0
# count       0.0   0.000000   1000.0              0.0

# %% [markdown]
# ##  Aggregation in Panda - groupby - agrouping

# %%
df.groupby(['product']).sum('price')
# Out:
#          quantity  price  extended amount  purchase_month  purchase_year  \
# product
# book         5340   5115           118356            1547         472446
# pen          5005   5271           115017            1491         456294
# poster       5827   6258           139008            1767         543111
# shirt        6249   6172           137889            1801         547149
#
#          purchase_quarter  new_price  new_extended_quantity
# product
# book                  594    5370.75              124273.80
# pen                   572    5534.55              120767.85
# poster                678    6570.90              145958.40
# shirt                 695    6480.60              144783.45

# %%
df.groupby(['product'])['quantity'].sum()
# Out:
# product
# book      5340
# pen       5005
# poster    5827
# shirt     6249
# Name: quantity, dtype: int64

# %%
product_column={'quantity': 'sum'}
df.groupby(['product']).agg(product_column)
# Out:
#          quantity
# product
# book         5340
# pen          5005
# poster       5827
# shirt        6249

# %%
product_column={'quantity': ['sum', 'mean']}
df.groupby(['product']).agg(product_column)
# Out:
#         quantity
#              sum       mean
# product
# book        5340  22.820513
# pen         5005  22.146018
# poster      5827  21.661710
# shirt       6249  23.059041

# %%
product_column={'quantity': ['sum', 'mean', 'min', 'max', 'std']}
df.groupby(['company', 'product']).agg(product_column)
# Out:
#                 quantity
#                      sum       mean min max        std
# company product
# Abatz   book          64  21.333333  -4  47  25.501634
#         pen            7   7.000000   7   7        NaN
#         poster        39  39.000000  39  39        NaN
# Agivu   book          11  11.000000  11  11        NaN
#         shirt         20  20.000000  20  20        NaN
# ...                  ...        ...  ..  ..        ...
# Zooxo   book          30  30.000000  30  30        NaN
#         shirt         85  42.500000  41  44   2.121320
# Zoozzy  pen           31  31.000000  31  31        NaN
#         poster        31  15.500000   0  31  21.920310
#         shirt         23  23.000000  23  23        NaN
#
# [731 rows x 5 columns]

# %%
product_column={'quantity': ['sum', 'mean', 'min', 'max', 'std']}
df.groupby(['company', 'product']).agg(product_column).reset_index()
# Out:
#     company product quantity
#                          sum       mean min max        std
# 0     Abatz    book       64  21.333333  -4  47  25.501634
# 1     Abatz     pen        7   7.000000   7   7        NaN
# 2     Abatz  poster       39  39.000000  39  39        NaN
# 3     Agivu    book       11  11.000000  11  11        NaN
# 4     Agivu   shirt       20  20.000000  20  20        NaN
# ..      ...     ...      ...        ...  ..  ..        ...
# 726   Zooxo    book       30  30.000000  30  30        NaN
# 727   Zooxo   shirt       85  42.500000  41  44   2.121320
# 728  Zoozzy     pen       31  31.000000  31  31        NaN
# 729  Zoozzy  poster       31  15.500000   0  31  21.920310
# 730  Zoozzy   shirt       23  23.000000  23  23        NaN
#
# [731 rows x 7 columns]

# %% [markdown]
# ##  Named Aggregations in Panda

# %%
df.groupby(['company']).agg(invoice_total = ('invoice', 'count'),
                            max_purchase = ('extended amount', 'max'))
# Out:
#            invoice_total  max_purchase
# company
# Abatz                  5          1410
# Agivu                  2           700
# Aibox                  2           828
# Ailane                 3           400
# Aimbo                  3           570
# ...                  ...           ...
# Zoonoodle              3           644
# Zooveo                 4           609
# Zoovu                  2           165
# Zooxo                  3           968
# Zoozzy                 4           620
#
# [351 rows x 2 columns]

# %% [markdown]
# ## Pivot tables and crosstab

# %%
pd.pivot_table(df, index=['company'], columns=['product'],
               values=['extended amount'], 
               aggfunc='sum',
               margins=True)
# Out:
#         extended amount
# product            book       pen    poster     shirt     All
# company
# Abatz            2063.0     140.0    1248.0       NaN    3451
# Agivu             385.0       NaN       NaN     700.0    1085
# Aibox              30.0     828.0       NaN       NaN     858
# Ailane            400.0    -105.0       0.0       NaN     295
# Aimbo               NaN     438.0       NaN    -165.0     273
# ...                 ...       ...       ...       ...     ...
# Zooveo              NaN     113.0     609.0     377.0    1099
# Zoovu             165.0       NaN       NaN     -56.0     109
# Zooxo             420.0       NaN       NaN    1378.0    1798
# Zoozzy              NaN     527.0     620.0     437.0    1584
# All            118356.0  115017.0  139008.0  137889.0  510270
#
# [352 rows x 5 columns]

# %%
pd.pivot_table(df, index=['company'], columns=['product'],
               values=['extended amount'], 
               aggfunc=['sum', 'min', 'max'],
               margins=True,
              fill_value=0)
# Out:
#                     sum                                             min       \
#         extended amount                                 extended amount
# product            book     pen  poster   shirt     All            book  pen
# company
# Abatz              2063     140    1248       0    3451             -40  140
# Agivu               385       0       0     700    1085             385    0
# Aibox                30     828       0       0     858              30  828
# Ailane              400    -105       0       0     295             400 -105
# Aimbo                 0     438       0    -165     273               0 -132
# ...                 ...     ...     ...     ...     ...             ...  ...
# Zooveo                0     113     609     377    1099               0  -30
# Zoovu               165       0       0     -56     109             165    0
# Zooxo               420       0       0    1378    1798             420    0
# ...

# %%
pd.pivot_table(df, index=['company'], columns=['product'],
               values=['extended amount'], 
               aggfunc=['sum'],
               margins=True,
              fill_value=0)
# Out:
#                     sum
#         extended amount
# product            book     pen  poster   shirt     All
# company
# Abatz              2063     140    1248       0    3451
# Agivu               385       0       0     700    1085
# Aibox                30     828       0       0     858
# Ailane              400    -105       0       0     295
# Aimbo                 0     438       0    -165     273
# ...                 ...     ...     ...     ...     ...
# Zooveo                0     113     609     377    1099
# Zoovu               165       0       0     -56     109
# Zooxo               420       0       0    1378    1798
# Zoozzy                0     527     620     437    1584
# All              118356  115017  139008  137889  510270
#
# [352 rows x 5 columns]

# %% [markdown]
# ## Crosstab function

# %%
pd.crosstab(df['company'], df['product'])
# Out:
# product    book  pen  poster  shirt
# company
# Abatz         3    1       1      0
# Agivu         1    0       0      1
# Aibox         1    1       0      0
# Ailane        1    1       1      0
# Aimbo         0    2       0      1
# ...         ...  ...     ...    ...
# Zoonoodle     1    1       0      1
# Zooveo        0    2       1      1
# Zoovu         1    0       0      1
# Zooxo         1    0       0      2
# Zoozzy        0    1       2      1
#
# [351 rows x 4 columns]

# %%
pd.crosstab(df['company'], df['product'], values=df['extended amount'], aggfunc='sum')
# Out:
# product      book    pen  poster   shirt
# company
# Abatz      2063.0  140.0  1248.0     NaN
# Agivu       385.0    NaN     NaN   700.0
# Aibox        30.0  828.0     NaN     NaN
# Ailane      400.0 -105.0     0.0     NaN
# Aimbo         NaN  438.0     NaN  -165.0
# ...           ...    ...     ...     ...
# Zoonoodle   527.0  644.0     NaN   308.0
# Zooveo        NaN  113.0   609.0   377.0
# Zoovu       165.0    NaN     NaN   -56.0
# Zooxo       420.0    NaN     NaN  1378.0
# Zoozzy        NaN  527.0   620.0   437.0
#
# [351 rows x 4 columns]

# %%
pd.crosstab(df['company'], df['product'], values=df['extended amount'], aggfunc='sum', normalize=True)
# Out:
# product        book       pen    poster     shirt
# company
# Abatz      0.004043  0.000274  0.002446  0.000000
# Agivu      0.000755  0.000000  0.000000  0.001372
# Aibox      0.000059  0.001623  0.000000  0.000000
# Ailane     0.000784 -0.000206  0.000000  0.000000
# Aimbo      0.000000  0.000858  0.000000 -0.000323
# ...             ...       ...       ...       ...
# Zoonoodle  0.001033  0.001262  0.000000  0.000604
# Zooveo     0.000000  0.000221  0.001193  0.000739
# Zoovu      0.000323  0.000000  0.000000 -0.000110
# Zooxo      0.000823  0.000000  0.000000  0.002701
# Zoozzy     0.000000  0.001033  0.001215  0.000856
#
# [351 rows x 4 columns]

# %%
pd.crosstab(df['company'], df['product'], values=df['extended amount'], aggfunc='sum', normalize='index')
# Out:
# product        book       pen    poster     shirt
# company
# Abatz      0.597798  0.040568  0.361634  0.000000
# Agivu      0.354839  0.000000  0.000000  0.645161
# Aibox      0.034965  0.965035  0.000000  0.000000
# Ailane     1.355932 -0.355932  0.000000  0.000000
# Aimbo      0.000000  1.604396  0.000000 -0.604396
# ...             ...       ...       ...       ...
# Zoonoodle  0.356322  0.435429  0.000000  0.208249
# Zooveo     0.000000  0.102821  0.554140  0.343039
# Zoovu      1.513761  0.000000  0.000000 -0.513761
# Zooxo      0.233593  0.000000  0.000000  0.766407
# Zoozzy     0.000000  0.332702  0.391414  0.275884
#
# [351 rows x 4 columns]

# %%
pd.crosstab(df['company'], df['product'], values=df['extended amount'], aggfunc='sum', normalize='columns')
# Out:
# product        book       pen    poster     shirt
# company
# Abatz      0.017430  0.001217  0.008978  0.000000
# Agivu      0.003253  0.000000  0.000000  0.005077
# Aibox      0.000253  0.007199  0.000000  0.000000
# Ailane     0.003380 -0.000913  0.000000  0.000000
# Aimbo      0.000000  0.003808  0.000000 -0.001197
# ...             ...       ...       ...       ...
# Zoonoodle  0.004453  0.005599  0.000000  0.002234
# Zooveo     0.000000  0.000982  0.004381  0.002734
# Zoovu      0.001394  0.000000  0.000000 -0.000406
# Zooxo      0.003549  0.000000  0.000000  0.009994
# Zoozzy     0.000000  0.004582  0.004460  0.003169
#
# [351 rows x 4 columns]

# %% [markdown]
# ## Panda I/O files

# %%
non_tabular_excel_file = Path.cwd() / 'data' / 'raw' / 'excel_complicated_document.xlsx'
#print(input_file)
df = pd.read_excel(non_tabular_excel_file)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.read_excel(non_tabular_excel_file, sheet_name='sales data')

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19
#
#    extended amount       Average Price       22.816
# 0              323  Standard Deviation     7.533269
# 1              420                 NaN          NaN
# 2              161      Total Qty Sold          NaN
# 3              203               shirt  6249.000000
# 4              684                book  5340.000000

# %%
df = pd.read_excel(non_tabular_excel_file, sheet_name='sales data', usecols='A:G')

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  extended amount
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17              323
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14              420
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23              161
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29              203
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19              684

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice          1000 non-null   object
#  1   company          1000 non-null   object
#  2   purchase_date    1000 non-null   datetime64[ns]
#  3   product          1000 non-null   object
#  4   quantity         1000 non-null   int64
#  5   price            1000 non-null   int64
#  6   extended amount  1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df_levels=pd.read_excel(non_tabular_excel_file, sheet_name='levels', header=2)

# %%
df_levels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   351 non-null    object
#  1   Notes          2 non-null      object
#  2   level          351 non-null    object
#  3   ZipCode        351 non-null    int64
#  4   update_month   351 non-null    int64
#  5   update_day     351 non-null    int64
#  6   update_year    351 non-null    int64
#  7   pct_to_target  351 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 22.1+ KB

# %%
df.head()
# Out:
#      invoice   company purchase_date product  quantity  price  extended amount
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17              323
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14              420
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23              161
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29              203
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19              684

# %%
df = pd.read_excel(non_tabular_excel_file, sheet_name='sales data', usecols='A, C:H')

# %%
df.head()
# Out:
#      invoice purchase_date product  quantity  price  extended amount  \
# 0  ZN-870-29    2019-03-05   shirt        19     17              323
# 1  JQ-501-63    2019-07-09    book        30     14              420
# 2  FI-165-58    2019-08-12  poster         7     23              161
# 3  XP-005-55    2019-11-18     pen         7     29              203
# 4  NB-917-18    2019-04-18  poster        36     19              684
#
#         Average Price
# 0  Standard Deviation
# 1                 NaN
# 2      Total Qty Sold
# 3               shirt
# 4                book

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice          1000 non-null   object
#  1   purchase_date    1000 non-null   datetime64[ns]
#  2   product          1000 non-null   object
#  3   quantity         1000 non-null   int64
#  4   price            1000 non-null   int64
#  5   extended amount  1000 non-null   int64
#  6   Average Price    6 non-null      object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df_levels=pd.read_excel(non_tabular_excel_file, 
                        sheet_name='levels', 
                        header=2, 
                        usecols='A,C:H', 
                        parse_dates={'update_date': [3,4,5]})

# %%
df_levels.head()
# Out:
#   update_date Company Name     level  ZipCode pct_to_target
# 0  2019-03-01        Abatz   diamond    14150          100%
# 1  2019-03-01        Agivu    silver    61354           90%
# 2  2019-03-01        Aibox  platinum     4442          105%
# 3  2019-03-01       Ailane    silver    78595           60%
# 4  2019-03-01        Aimbo   diamond    55447          100%

# %%
df_levels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   update_date    351 non-null    datetime64[ns]
#  1   Company Name   351 non-null    object
#  2   level          351 non-null    object
#  3   ZipCode        351 non-null    int64
#  4   pct_to_target  351 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 13.8+ KB

# %%
df_levels=pd.read_excel(non_tabular_excel_file, 
                        sheet_name='levels', 
                        header=2, 
                        usecols='A,C:H', 
                        parse_dates={'update_date': [3,4,5]}, 
                        dtype={'ZipCode': 'object'})

# %%
df_levels.head()
# Out:
#   update_date Company Name     level ZipCode pct_to_target
# 0  2019-03-01        Abatz   diamond   14150          100%
# 1  2019-03-01        Agivu    silver   61354           90%
# 2  2019-03-01        Aibox  platinum   04442          105%
# 3  2019-03-01       Ailane    silver   78595           60%
# 4  2019-03-01        Aimbo   diamond   55447          100%

# %%
def convert_percent(val):
    new_val = val.replace('%', '')
    return float(new_val)/100

# %%
df_levels['pct_to_target'].apply(convert_percent)
# Out:
# 0      1.00
# 1      0.90
# 2      1.05
# 3      0.60
# 4      1.00
#        ...
# 346    1.05
# 347    0.60
# 348    1.00
# 349    0.80
# 350    1.05
# Name: pct_to_target, Length: 351, dtype: float64

# %%
df_levels = pd.read_excel(non_tabular_excel_file,
                          sheet_name='levels',
                          header=2,
                          usecols='A,C:H',
                          parse_dates={'update_date': [3,4,5]},
                          dtype={'ZipCode': 'object'},
                          converters={'pct_to_target': convert_percent})
df_levels.head()
# Out:
#   update_date Company Name     level ZipCode  pct_to_target
# 0  2019-03-01        Abatz   diamond   14150           1.00
# 1  2019-03-01        Agivu    silver   61354           0.90
# 2  2019-03-01        Aibox  platinum   04442           1.05
# 3  2019-03-01       Ailane    silver   78595           0.60
# 4  2019-03-01        Aimbo   diamond   55447           1.00

# %% [markdown]
# ## Save data to Excel file

# %%
df_sales = pd.read_excel(non_tabular_excel_file, sheet_name='sales data', usecols='A:G')
df_sales.head()
# Out:
#      invoice   company purchase_date product  quantity  price  extended amount
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17              323
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14              420
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23              161
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29              203
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19              684

# %%
sales_summary = df_sales.groupby(['company', 'product']).agg({'extended amount': 'sum'})
sales_summary
# Out:
#                  extended amount
# company product
# Abatz   book                2063
#         pen                  140
#         poster              1248
# Agivu   book                 385
#         shirt                700
# ...                          ...
# Zooxo   book                 420
#         shirt               1378
# Zoozzy  pen                  527
#         poster               620
#         shirt                437
#
# [731 rows x 1 columns]

# %%
sales_avg = df_sales.agg({'extended amount': ['sum', 'mean'], 'price': ['mean']}).fillna(0)
sales_avg
# Out:
#       extended amount   price
# sum         510270.00   0.000
# mean           510.27  22.816

# %% [markdown]
# ## Pivot table

# %%
product_summary = pd.pivot_table(data=df_sales, index=['product'], 
                                 values=['extended amount'],
                                aggfunc=['sum', 'mean', 'count'])
product_summary
# Out:
#                     sum            mean           count
#         extended amount extended amount extended amount
# product
# book             118356      505.794872             234
# pen              115017      508.924779             226
# poster           139008      516.758364             269
# shirt            137889      508.815498             271

# %%
report_file1= Path.cwd() / 'data' / 'raw' / 'report_file1.xlsx'
sales_summary.to_excel(report_file1)

# %% [markdown]
# ## Using xlsx writer

# %%
writer = pd.ExcelWriter(report_file1, engine='xlsxwriter')
sales_summary.to_excel(writer, sheet_name='Sales_Summary')
sales_avg.to_excel(writer, sheet_name='Sales_Summary', startcol=4)
product_summary.to_excel(writer, sheet_name='Product_Summary')

# %%
# %%timeit
df_sales.groupby(['product']).agg({'invoice': 'sum'}).style.format('${:,.2f}')
# Out:
# 301 μs ± 984 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Case study walk through: Sales commissions
